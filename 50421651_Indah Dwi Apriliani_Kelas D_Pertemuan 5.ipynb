# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import io

# %%
DATA_URL = 'data_kaggle.csv'

# %%
def load_data():
    data = pd.read_csv('data_kaggle.csv')
    return data

# %%
data = load_data()

# %%
from IPython.display import display, Markdown

# %%
# Menampilkan judul di Jupyter Notebook
display(Markdown('# Property Listings in Kuala Lumpur'))
# Out:
# # Property Listings in Kuala Lumpur

# %%
# Menampilkan header dan subheader
print('--== Data Understanding ==--')
print('\nRaw Dataset\n')
# Out:
# --== Data Understanding ==--
#
# Raw Dataset

# %%
# Menampilkan 5 baris pertama dari DataFrame
data.head()
# Out:
#                           Location         Price Rooms  Bathrooms  Car Parks  \
# 0               KLCC, Kuala Lumpur  RM 1,250,000   2+1        3.0        2.0
# 1  Damansara Heights, Kuala Lumpur  RM 6,800,000     6        7.0        NaN
# 2            Dutamas, Kuala Lumpur  RM 1,030,000     3        4.0        2.0
# 3             Cheras, Kuala Lumpur           NaN   NaN        NaN        NaN
# 4        Bukit Jalil, Kuala Lumpur    RM 900,000   4+1        3.0        2.0
#
#           Property Type                      Size        Furnishing
# 0    Serviced Residence  Built-up : 1,335 sq. ft.   Fully Furnished
# 1              Bungalow  Land area : 6900 sq. ft.  Partly Furnished
# 2  Condominium (Corner)  Built-up : 1,875 sq. ft.  Partly Furnished
# 3                   NaN                       NaN               NaN
# 4  Condominium (Corner)  Built-up : 1,513 sq. ft.  Partly Furnished

# %%
display(data.describe(include='all'))
# Out:
#                         Location         Price  Rooms     Bathrooms  \
# count                      53883         53635  52177  51870.000000
# unique                       112          4280     43           NaN
# top     Mont Kiara, Kuala Lumpur  RM 1,200,000      3           NaN
# freq                        5897           721  14249           NaN
# mean                         NaN           NaN    NaN      3.073434
# std                          NaN           NaN    NaN      1.631079
# min                          NaN           NaN    NaN      1.000000
# 25%                          NaN           NaN    NaN      2.000000
# 50%                          NaN           NaN    NaN      2.000000
# 75%                          NaN           NaN    NaN      4.000000
# max                          NaN           NaN    NaN     20.000000
#
#            Car Parks Property Type                       Size  \
# count   36316.000000         53858                      52820
# ...

# %%
display(data.isna().sum())
# Out:
# Location             0
# Price              248
# Rooms             1706
# Bathrooms         2013
# Car Parks        17567
# Property Type       25
# Size              1063
# Furnishing        6930
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 4467

# %%
df_sample = data.sample(frac=0.2)
df_sample = df_sample.reset_index(drop=True)

# %%
df_sample.describe(include='all')
# Out:
#                         Location         Price  Rooms     Bathrooms  \
# count                      10777         10719  10425  10379.000000
# unique                        75          1711     37           NaN
# top     Mont Kiara, Kuala Lumpur  RM 1,200,000      3           NaN
# freq                        1183           168   2880           NaN
# mean                         NaN           NaN    NaN      3.074863
# std                          NaN           NaN    NaN      1.647508
# min                          NaN           NaN    NaN      1.000000
# 25%                          NaN           NaN    NaN      2.000000
# 50%                          NaN           NaN    NaN      2.000000
# 75%                          NaN           NaN    NaN      4.000000
# max                          NaN           NaN    NaN     20.000000
#
#           Car Parks Property Type                       Size        Furnishing
# ...

# %%
df_price = df_sample.copy()

# %%
df_price['Price'] = df_price['Price'].replace({'RM ': '', ',': ''}, regex=True).astype(float)

# %%
df_floatPrice = df_sample.copy()
df_floatPrice['Price'] = df_price['Price']

# %%
df_floatPrice.head()
# Out:
#                                           Location      Price Rooms  \
# 0                             Cheras, Kuala Lumpur  4300000.0     9
# 1                           Segambut, Kuala Lumpur   638000.0     2
# 2                            Seputeh, Kuala Lumpur  5500000.0   5+1
# 3                        Bukit Jalil, Kuala Lumpur   590000.0     4
# 4  Jalan Klang Lama (Old Klang Road), Kuala Lumpur   350000.0     3
#
#    Bathrooms  Car Parks               Property Type                      Size  \
# 0       10.0        5.0                    Bungalow  Land area : 7500 sq. ft.
# 1        2.0        2.0  Condominium (Intermediate)  Built-up : 1,021 sq. ft.
# 2        6.0        3.0     Bungalow (Intermediate)  Land area : 4844 sq. ft.
# 3        2.0        1.0        Condominium (EndLot)  Land area : 1252 sq. ft.
# 4        3.0        NaN          Serviced Residence                       NaN
#
#          Furnishing
# 0  Partly Furnished
# 1  Partly Furnished
# 2  Partly Furnished
# ...
